# %%
# Portfolio Summary – Data Analytics Projects (Week 1–Week 5)

This notebook presents a consolidated summary of all data analytics projects
completed during the internship period. The objective is to integrate insights,
visualizations, and outcomes into a unified portfolio for evaluation and presentation.

# %%
## Project Overview

| Week | Project Title | Key Focus |
|-----|--------------|-----------|
| Week 1 | Business Sales Analysis | Sales trends, customer behavior, product performance |
| Week 2 | Healthcare Data Analysis | Patient statistics, treatment outcomes, hospital metrics |
| Week 3 | Sports Analytics | Player performance, team statistics |
| Week 4 | Financial Market Analysis | Stock trends, portfolio analysis, risk assessment |
| Week 5 | E-commerce Analytics | Customer segmentation, purchase patterns, recommendations |

# %%
## Tools & Technologies Used
- Python
- Pandas, NumPy
- Matplotlib
- Jupyter Notebook
- CSV Datasets

# %%
## Week 1: Business Sales Analysis

**Objective:**  
Analyze sales performance, customer purchasing behavior, and product trends.

**Key Insights:**
- Identified top-performing products
- Analyzed monthly and regional sales trends
- Observed repeat customer behavior

# %%
## Week 2: Healthcare Data Analysis

**Objective:**  
Evaluate patient demographics, treatment success rates, and hospital performance.

**Key Insights:**
- Middle-aged patients formed the largest admission group
- Medication-based treatments showed higher success rates
- ICU departments had higher readmission rates

# %%
## Week 3: Sports Analytics

**Objective:**  
Analyze player performance and team statistics.

**Key Insights:**
- Identified top-performing players based on match statistics
- Compared team performance across matches
- Evaluated consistency metrics

# %%
## Week 4: Financial Market Analysis

**Objective:**  
Analyze stock trends, portfolio performance, and investment risk.

**Key Insights:**
- Identified long-term stock trends
- Evaluated portfolio diversification
- Assessed risk using volatility measures

# %%
## Week 5: E-commerce Analytics

**Objective:**  
Analyze customer segmentation, purchase behavior, and product recommendations.

**Key Insights:**
- Segmented customers based on purchasing patterns
- Identified high-value customers
- Generated recommendation insights based on order history

# %%
## Dashboards & Visualizations

Interactive dashboards and visual summaries were developed in individual project notebooks
to effectively communicate insights. These dashboards highlight key KPIs and trends
identified during analysis.

# %%
## Conclusion

This portfolio integrates all analytical projects completed during the internship into
a single, cohesive presentation. The work demonstrates practical application of data
analytics techniques, effective data visualization, and professional reporting skills.
The portfolio is suitable for academic evaluation and industry presentation.

# %%
**Prepared by:**Python Developer Intern  
**Internship Duration:** Week 1 – Week 6  
**Focus:** Data Analytics & Visualization
